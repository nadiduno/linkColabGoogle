# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiduno/linkColabGoogle/blob/main/bdeducacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dados do Sistema Educacional Brasileiro (SEB)
#
# <br> Quantidade de alunos estrangeiros por nacionalidade
# [Dados disponível em](https://dados.educacao.sp.gov.br/dataset/quantidade-de-alunos-estrangeiros-por-nacionalidade)
#
# <br>O banco de dados de Alunos Estrangeiros por Nacionalidade apresenta o número de alunos estrangeiros matriculados em todas as redes de ensino do Estado, por nacionalidade.
#
# <br>Grupo de Estudo | Dados | Toti Diversidade - Agosto/2023

# %% [markdown]
# #Importando Bibliotecas

# %%
#Importing depending libraries to read csv files
from pandas.io.parsers.readers import read_csv
import pandas as pd
import matplotlib.pyplot as plt #para fazer os gráficos
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #Importando Dados

# %%
## Dataset is now stored in a Pandas Dataframe

url_2019_1 = 'https://raw.githubusercontent.com/juan-jm90/Analise_grupo_de_estudos/main/VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_20190517.csv'

url_2020_1 = 'https://raw.githubusercontent.com/juan-jm90/Analise_grupo_de_estudos/main/VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_31012020.csv'

url_2020_2 = 'https://raw.githubusercontent.com/juan-jm90/Analise_grupo_de_estudos/main/VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_31122020.csv'

url_2021_1 = 'https://raw.githubusercontent.com/juan-jm90/Analise_grupo_de_estudos/main/VW_MENSAL_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_31032021.csv'

url_2021_2 = 'https://raw.githubusercontent.com/juan-jm90/Analise_grupo_de_estudos/main/Estrangeiros_por_nacionalidade_2021_2.csv'

url_2022_1 = 'https://raw.githubusercontent.com/juan-jm90/Analise_grupo_de_estudos/main/Estrangeiros_por_nacionalidade_2022_1.csv'

# %%
#Reading the files uploades with the read csv methods
df_2019_1 = pd.read_csv(url_2019_1, encoding='utf-8', sep=";")
df_2020_1 = pd.read_csv(url_2020_1, encoding='utf-8', sep=";")
df_2020_2 = pd.read_csv(url_2020_2,  encoding='utf-8', sep=";")
df_2021_1 = pd.read_csv(url_2021_1,  encoding='utf-8', sep=";")
df_2021_2 = pd.read_csv(url_2021_2,  encoding='latin-1', sep=";")
df_2022_1 = pd.read_csv(url_2022_1,  encoding='latin-1', sep=";")

# %% [markdown]
# #Tratando os Dados

# %%
#changing in table df_2019_1 the column name "N° alunos" para "N° ALUNOS"
df_2019_1_ren = df_2019_1.rename(columns={"Nº alunos":"Nº ALUNOS"})

# %%
#Adicionando o ano nas tabelas
df_2019_1_ano = df_2019_1_ren.assign(ANO= 2019)
df_2020_1_ano = df_2020_1.assign(ANO= 2020)
df_2020_2_ano = df_2020_2.assign(ANO= 2020)
df_2021_1_ano = df_2021_1.assign(ANO= 2021)
df_2021_2_ano = df_2021_2.assign(ANO= 2021)
df_2022_1_ano = df_2022_1.assign(ANO= 2022)

# %%
#Concatenar tabelas
lista_tabelas = [df_2019_1_ano, df_2020_1_ano, df_2020_2_ano, df_2021_1_ano, df_2021_2_ano, df_2022_1_ano]
tabela_todos = pd.concat(lista_tabelas)
tabela_todos
# Out:
#                  NOMEDEP              DE           DISTR        MUN  TIPOESC  \
# 0      ESTADUAL - OUTROS  CAMPINAS LESTE  CAMPINAS LESTE   CAMPINAS       27
# 1      ESTADUAL - OUTROS    CENTRO OESTE  RAPOSO TAVARES  SAO PAULO       11
# 2      ESTADUAL - OUTROS      CENTRO SUL      BELA VISTA  SAO PAULO       11
# 3      ESTADUAL - OUTROS        SOROCABA        SOROCABA   SOROCABA       11
# 4      ESTADUAL - OUTROS         TAUBATE        CACAPAVA   CACAPAVA       11
# ...                  ...             ...             ...        ...      ...
# 13825  ESTADUAL - OUTROS         JUNDIAI         JUNDIAI    JUNDIAI       11
# 13826  ESTADUAL - OUTROS         LESTE 5      ARICANDUVA  SAO PAULO       11
# 13827  ESTADUAL - OUTROS         LESTE 5      ARICANDUVA  SAO PAULO       11
# 13828  ESTADUAL - OUTROS         LESTE 4     ARTUR ALVIM  SAO PAULO       11
# 13829  ESTADUAL - OUTROS         LESTE 4     ARTUR ALVIM  SAO PAULO       11
#
#        COD_ESC                                 NOMESC    DS_PAIS  Nº ALUNOS  \
# 0        45949  CAMPINAS COLEGIO TECNICO DE - UNICAMP     França          1
# 1       438820                    RAPOSO TAVARES ETEC  Argentina          1
# 2       299364         MARIA AUGUSTA SARAIVA DRA ETEC    Bolívia          2
# 3        16354           RUBENS DE FARIA E SOUZA ETEC       Peru          1
# 4        14308                  MACHADO DE ASSIS ETEC   Portugal          1
# ...        ...                                    ...        ...        ...
# 13825    45986        VASCO ANTONIO VENCHIARUTTI ETEC   Colômbia          1
# 13826   405243                   VILA FORMOSA ETEC DE     Angola          1
# 13827   405243                   VILA FORMOSA ETEC DE    Bolívia          1
# 13828   925871                        ZONA LESTE ETEC    Bolívia          3
# 13829   925871                        ZONA LESTE ETEC      Japão          1
#
#         ANO
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 13825  2022
# 13826  2022
# 13827  2022
# 13828  2022
# 13829  2022
#
# [70574 rows x 10 columns]

# %%
#Trocando as maiúsculas
dados = tabela_todos.applymap(lambda s:s.lower().capitalize() if type(s) == str else s)
dados
# Out:
#                  NOMEDEP              DE           DISTR        MUN  TIPOESC  \
# 0      Estadual - outros  Campinas leste  Campinas leste   Campinas       27
# 1      Estadual - outros    Centro oeste  Raposo tavares  Sao paulo       11
# 2      Estadual - outros      Centro sul      Bela vista  Sao paulo       11
# 3      Estadual - outros        Sorocaba        Sorocaba   Sorocaba       11
# 4      Estadual - outros         Taubate        Cacapava   Cacapava       11
# ...                  ...             ...             ...        ...      ...
# 13825  Estadual - outros         Jundiai         Jundiai    Jundiai       11
# 13826  Estadual - outros         Leste 5      Aricanduva  Sao paulo       11
# 13827  Estadual - outros         Leste 5      Aricanduva  Sao paulo       11
# 13828  Estadual - outros         Leste 4     Artur alvim  Sao paulo       11
# 13829  Estadual - outros         Leste 4     Artur alvim  Sao paulo       11
#
#        COD_ESC                                 NOMESC    DS_PAIS  Nº ALUNOS  \
# 0        45949  Campinas colegio tecnico de - unicamp     França          1
# 1       438820                    Raposo tavares etec  Argentina          1
# 2       299364         Maria augusta saraiva dra etec    Bolívia          2
# 3        16354           Rubens de faria e souza etec       Peru          1
# 4        14308                  Machado de assis etec   Portugal          1
# ...        ...                                    ...        ...        ...
# 13825    45986        Vasco antonio venchiarutti etec   Colômbia          1
# 13826   405243                   Vila formosa etec de     Angola          1
# 13827   405243                   Vila formosa etec de    Bolívia          1
# 13828   925871                        Zona leste etec    Bolívia          3
# 13829   925871                        Zona leste etec      Japão          1
#
#         ANO
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 13825  2022
# 13826  2022
# 13827  2022
# 13828  2022
# 13829  2022
#
# [70574 rows x 10 columns]

# %%
#Usando o DIC para renomear as columnas
dados.rename(columns={'NOMEDEP': 'Clasificaçõ','DE': 'Dependência','DISTR': 'Distrito','MUN': 'Município','TIPOESC': 'Tipo da Escola','COD_ESC': 'Código da Escola','NOMESC': 'Nome Escola','DS_PAIS': 'País de Origem','Nº ALUNOS': 'Número de alunos','ANO': 'Ano'}, inplace=True)
dados
# Out:
#              Clasificaçõ     Dependência        Distrito  Município  \
# 0      Estadual - outros  Campinas leste  Campinas leste   Campinas
# 1      Estadual - outros    Centro oeste  Raposo tavares  Sao paulo
# 2      Estadual - outros      Centro sul      Bela vista  Sao paulo
# 3      Estadual - outros        Sorocaba        Sorocaba   Sorocaba
# 4      Estadual - outros         Taubate        Cacapava   Cacapava
# ...                  ...             ...             ...        ...
# 13825  Estadual - outros         Jundiai         Jundiai    Jundiai
# 13826  Estadual - outros         Leste 5      Aricanduva  Sao paulo
# 13827  Estadual - outros         Leste 5      Aricanduva  Sao paulo
# 13828  Estadual - outros         Leste 4     Artur alvim  Sao paulo
# 13829  Estadual - outros         Leste 4     Artur alvim  Sao paulo
#
#        Tipo da Escola  Código da Escola  \
# 0                  27             45949
# 1                  11            438820
# 2                  11            299364
# 3                  11             16354
# 4                  11             14308
# ...               ...               ...
# 13825              11             45986
# 13826              11            405243
# 13827              11            405243
# 13828              11            925871
# 13829              11            925871
#
#                                  Nome Escola País de Origem  Número de alunos  \
# 0      Campinas colegio tecnico de - unicamp         França                 1
# 1                        Raposo tavares etec      Argentina                 1
# 2             Maria augusta saraiva dra etec        Bolívia                 2
# 3               Rubens de faria e souza etec           Peru                 1
# 4                      Machado de assis etec       Portugal                 1
# ...                                      ...            ...               ...
# 13825        Vasco antonio venchiarutti etec       Colômbia                 1
# 13826                   Vila formosa etec de         Angola                 1
# 13827                   Vila formosa etec de        Bolívia                 1
# 13828                        Zona leste etec        Bolívia                 3
# 13829                        Zona leste etec          Japão                 1
#
#         Ano
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 13825  2022
# 13826  2022
# 13827  2022
# 13828  2022
# 13829  2022
#
# [70574 rows x 10 columns]

# %%
#Conhecendo os dados
print('Clasificaçõ')
dados['Clasificaçõ'].value_counts()
# Out:
# Clasificaçõ
# Estadual - se        30631
# Municipal            20378
# Privada              18545
# Estadual - outros     1013
# Federal                  7
# Name: Clasificaçõ, dtype: int64

# %%
#O sistema se classifica em Estadual, Municipal, Privada e Federal, vamos a remplazar
dados['Clasificaçõ'] = dados['Clasificaçõ'].str.replace('Estadual - se', 'Estadual')
dados['Clasificaçõ'] = dados['Clasificaçõ'].str.replace('Estadual - outros', 'Estadual')
print('Clasificaçõ')
dados['Clasificaçõ'].value_counts()
# Out:
# Clasificaçõ
# Estadual     31644
# Municipal    20378
# Privada      18545
# Federal          7
# Name: Clasificaçõ, dtype: int64

# %%
print('País de Origem')
dados['País de Origem'].value_counts()
# Out:
# País de Origem
# Venezuela    10843
# Bolívia       9941
# Japão         7626
# Haiti         6339
# Colômbia      3628
#              ...
# Sri lanka        1
# Etiópia          1
# Botswana         1
# Fiji             1
# Kuwait           1
# Name: País de Origem, Length: 188, dtype: int64

# %%
#Verificando não ter campos vazios, se retorna true tem campos vazios nessa columna
dados['Clasificaçõ'].isna().any()
# Out:
# False

# %%
print(f"Quantidades de registros \n{len(dados)} \n")
print(f"Estatísticas geral dos dados \n\n")
dados.describe(include='all').head()
# Out:
# Quantidades de registros
# 70574
#
# Estatísticas geral dos dados
#        Clasificaçõ Dependência  Distrito  Município  Tipo da Escola  \
# count        70574       70574     70574      70574    70574.000000
# unique           4          92       647        482             NaN
# top       Estadual      Centro  Sorocaba  Sao paulo             NaN
# freq         31644        3358      1636      24065             NaN
# mean           NaN         NaN       NaN        NaN        5.504152
#
#         Código da Escola                                    Nome Escola  \
# count       70574.000000                                          70574
# unique               NaN                                          12317
# top                  NaN  Penitenciaria cabo p m marcelo pires da silva
# freq                 NaN                                            176
# mean       232835.418794                                            NaN
#
#        País de Origem  Número de alunos           Ano
# count           70574      70574.000000  70574.000000
# unique            188               NaN           NaN
# top         Venezuela               NaN           NaN
# freq            10843               NaN           NaN
# mean              NaN          2.076105   2020.630827

# %%
dados
# Out:
#       Clasificaçõ     Dependência        Distrito  Município  Tipo da Escola  \
# 0        Estadual  Campinas leste  Campinas leste   Campinas              27
# 1        Estadual    Centro oeste  Raposo tavares  Sao paulo              11
# 2        Estadual      Centro sul      Bela vista  Sao paulo              11
# 3        Estadual        Sorocaba        Sorocaba   Sorocaba              11
# 4        Estadual         Taubate        Cacapava   Cacapava              11
# ...           ...             ...             ...        ...             ...
# 13825    Estadual         Jundiai         Jundiai    Jundiai              11
# 13826    Estadual         Leste 5      Aricanduva  Sao paulo              11
# 13827    Estadual         Leste 5      Aricanduva  Sao paulo              11
# 13828    Estadual         Leste 4     Artur alvim  Sao paulo              11
# 13829    Estadual         Leste 4     Artur alvim  Sao paulo              11
#
#        Código da Escola                            Nome Escola País de Origem  \
# 0                 45949  Campinas colegio tecnico de - unicamp         França
# 1                438820                    Raposo tavares etec      Argentina
# 2                299364         Maria augusta saraiva dra etec        Bolívia
# 3                 16354           Rubens de faria e souza etec           Peru
# 4                 14308                  Machado de assis etec       Portugal
# ...                 ...                                    ...            ...
# 13825             45986        Vasco antonio venchiarutti etec       Colômbia
# 13826            405243                   Vila formosa etec de         Angola
# 13827            405243                   Vila formosa etec de        Bolívia
# 13828            925871                        Zona leste etec        Bolívia
# 13829            925871                        Zona leste etec          Japão
#
#        Número de alunos   Ano
# 0                     1  2019
# 1                     1  2019
# 2                     2  2019
# 3                     1  2019
# 4                     1  2019
# ...                 ...   ...
# 13825                 1  2022
# 13826                 1  2022
# 13827                 1  2022
# 13828                 3  2022
# 13829                 1  2022
#
# [70574 rows x 10 columns]

# %% [markdown]
# #Normalizando as tabelas da Base de Dados

# %%
#Criando novas columnas para os codigos usando labelEncoder
#Para normalizar as tabelas da BD
dadosBD = dados
convertidor = LabelEncoder()

# %%
dadosBD.insert(0, 'Cod Cla', None)
dadosBD['Cod Cla'] = convertidor.fit_transform(dadosBD['Clasificaçõ'])
dadosBD

# %%
dadosBD.insert(2, 'Cod Dep', None)
dadosBD['Cod Dep'] = convertidor.fit_transform(dadosBD['Dependência'])
dadosBD
# Out:
#        Cod Cla Clasificaçõ  Cod Dep     Dependência        Distrito  \
# 0            0    Estadual       14  Campinas leste  Campinas leste
# 1            0    Estadual       21    Centro oeste  Raposo tavares
# 2            0    Estadual       22      Centro sul      Bela vista
# 3            0    Estadual       80        Sorocaba        Sorocaba
# 4            0    Estadual       88         Taubate        Cacapava
# ...        ...         ...      ...             ...             ...
# 13825        0    Estadual       41         Jundiai         Jundiai
# 13826        0    Estadual       46         Leste 5      Aricanduva
# 13827        0    Estadual       46         Leste 5      Aricanduva
# 13828        0    Estadual       45         Leste 4     Artur alvim
# 13829        0    Estadual       45         Leste 4     Artur alvim
#
#        Município  Tipo da Escola  Código da Escola  \
# 0       Campinas              27             45949
# 1      Sao paulo              11            438820
# 2      Sao paulo              11            299364
# 3       Sorocaba              11             16354
# 4       Cacapava              11             14308
# ...          ...             ...               ...
# 13825    Jundiai              11             45986
# 13826  Sao paulo              11            405243
# 13827  Sao paulo              11            405243
# 13828  Sao paulo              11            925871
# 13829  Sao paulo              11            925871
#
#                                  Nome Escola País de Origem  Número de alunos  \
# 0      Campinas colegio tecnico de - unicamp         França                 1
# 1                        Raposo tavares etec      Argentina                 1
# 2             Maria augusta saraiva dra etec        Bolívia                 2
# 3               Rubens de faria e souza etec           Peru                 1
# 4                      Machado de assis etec       Portugal                 1
# ...                                      ...            ...               ...
# 13825        Vasco antonio venchiarutti etec       Colômbia                 1
# 13826                   Vila formosa etec de         Angola                 1
# 13827                   Vila formosa etec de        Bolívia                 1
# 13828                        Zona leste etec        Bolívia                 3
# 13829                        Zona leste etec          Japão                 1
#
#         Ano
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 13825  2022
# 13826  2022
# 13827  2022
# 13828  2022
# 13829  2022
#
# [70574 rows x 12 columns]

# %%
dadosBD.insert(4, 'Cod Dist', None)
dadosBD['Cod Dist'] = convertidor.fit_transform(dadosBD['Distrito'])
dadosBD
# Out:
#        Cod Cla Clasificaçõ  Cod Dep     Dependência  Cod Dist        Distrito  \
# 0            0    Estadual       14  Campinas leste       111  Campinas leste
# 1            0    Estadual       21    Centro oeste       479  Raposo tavares
# 2            0    Estadual       22      Centro sul        66      Bela vista
# 3            0    Estadual       80        Sorocaba       581        Sorocaba
# 4            0    Estadual       88         Taubate        97        Cacapava
# ...        ...         ...      ...             ...       ...             ...
# 13825        0    Estadual       41         Jundiai       309         Jundiai
# 13826        0    Estadual       46         Leste 5        38      Aricanduva
# 13827        0    Estadual       46         Leste 5        38      Aricanduva
# 13828        0    Estadual       45         Leste 4        40     Artur alvim
# 13829        0    Estadual       45         Leste 4        40     Artur alvim
#
#        Município  Tipo da Escola  Código da Escola  \
# 0       Campinas              27             45949
# 1      Sao paulo              11            438820
# 2      Sao paulo              11            299364
# 3       Sorocaba              11             16354
# 4       Cacapava              11             14308
# ...          ...             ...               ...
# 13825    Jundiai              11             45986
# 13826  Sao paulo              11            405243
# 13827  Sao paulo              11            405243
# 13828  Sao paulo              11            925871
# 13829  Sao paulo              11            925871
#
#                                  Nome Escola País de Origem  Número de alunos  \
# 0      Campinas colegio tecnico de - unicamp         França                 1
# 1                        Raposo tavares etec      Argentina                 1
# 2             Maria augusta saraiva dra etec        Bolívia                 2
# 3               Rubens de faria e souza etec           Peru                 1
# 4                      Machado de assis etec       Portugal                 1
# ...                                      ...            ...               ...
# 13825        Vasco antonio venchiarutti etec       Colômbia                 1
# 13826                   Vila formosa etec de         Angola                 1
# 13827                   Vila formosa etec de        Bolívia                 1
# 13828                        Zona leste etec        Bolívia                 3
# 13829                        Zona leste etec          Japão                 1
#
#         Ano
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 13825  2022
# 13826  2022
# 13827  2022
# 13828  2022
# 13829  2022
#
# [70574 rows x 13 columns]

# %%
dadosBD.insert(6, 'Cod Mun', None)
dadosBD['Cod Mun'] = convertidor.fit_transform(dadosBD['Município'])
dadosBD
# Out:
#        Cod Cla Clasificaçõ  Cod Dep     Dependência  Cod Dist        Distrito  \
# 0            0    Estadual       14  Campinas leste       111  Campinas leste
# 1            0    Estadual       21    Centro oeste       479  Raposo tavares
# 2            0    Estadual       22      Centro sul        66      Bela vista
# 3            0    Estadual       80        Sorocaba       581        Sorocaba
# 4            0    Estadual       88         Taubate        97        Cacapava
# ...        ...         ...      ...             ...       ...             ...
# 13825        0    Estadual       41         Jundiai       309         Jundiai
# 13826        0    Estadual       46         Leste 5        38      Aricanduva
# 13827        0    Estadual       46         Leste 5        38      Aricanduva
# 13828        0    Estadual       45         Leste 4        40     Artur alvim
# 13829        0    Estadual       45         Leste 4        40     Artur alvim
#
#        Cod Mun  Município  Tipo da Escola  Código da Escola  \
# 0           86   Campinas              27             45949
# 1          426  Sao paulo              11            438820
# 2          426  Sao paulo              11            299364
# 3          442   Sorocaba              11             16354
# 4           75   Cacapava              11             14308
# ...        ...        ...             ...               ...
# 13825      232    Jundiai              11             45986
# 13826      426  Sao paulo              11            405243
# 13827      426  Sao paulo              11            405243
# 13828      426  Sao paulo              11            925871
# 13829      426  Sao paulo              11            925871
#
#                                  Nome Escola País de Origem  Número de alunos  \
# 0      Campinas colegio tecnico de - unicamp         França                 1
# 1                        Raposo tavares etec      Argentina                 1
# 2             Maria augusta saraiva dra etec        Bolívia                 2
# 3               Rubens de faria e souza etec           Peru                 1
# 4                      Machado de assis etec       Portugal                 1
# ...                                      ...            ...               ...
# 13825        Vasco antonio venchiarutti etec       Colômbia                 1
# 13826                   Vila formosa etec de         Angola                 1
# 13827                   Vila formosa etec de        Bolívia                 1
# 13828                        Zona leste etec        Bolívia                 3
# 13829                        Zona leste etec          Japão                 1
#
#         Ano
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 13825  2022
# 13826  2022
# 13827  2022
# 13828  2022
# 13829  2022
#
# [70574 rows x 14 columns]

# %%
dadosBD.insert(11, 'Cod País', None)
dadosBD['Cod País'] = convertidor.fit_transform(dadosBD['País de Origem'])
dadosBD
# Out:
#        Cod Cla Clasificaçõ  Cod Dep     Dependência  Cod Dist        Distrito  \
# 0            0    Estadual       14  Campinas leste       111  Campinas leste
# 1            0    Estadual       21    Centro oeste       479  Raposo tavares
# 2            0    Estadual       22      Centro sul        66      Bela vista
# 3            0    Estadual       80        Sorocaba       581        Sorocaba
# 4            0    Estadual       88         Taubate        97        Cacapava
# ...        ...         ...      ...             ...       ...             ...
# 13825        0    Estadual       41         Jundiai       309         Jundiai
# 13826        0    Estadual       46         Leste 5        38      Aricanduva
# 13827        0    Estadual       46         Leste 5        38      Aricanduva
# 13828        0    Estadual       45         Leste 4        40     Artur alvim
# 13829        0    Estadual       45         Leste 4        40     Artur alvim
#
#        Cod Mun  Município  Tipo da Escola  Código da Escola  \
# 0           86   Campinas              27             45949
# 1          426  Sao paulo              11            438820
# 2          426  Sao paulo              11            299364
# 3          442   Sorocaba              11             16354
# 4           75   Cacapava              11             14308
# ...        ...        ...             ...               ...
# 13825      232    Jundiai              11             45986
# 13826      426  Sao paulo              11            405243
# 13827      426  Sao paulo              11            405243
# 13828      426  Sao paulo              11            925871
# 13829      426  Sao paulo              11            925871
#
#                                  Nome Escola  Cod País País de Origem  \
# 0      Campinas colegio tecnico de - unicamp        69         França
# 1                        Raposo tavares etec         6      Argentina
# 2             Maria augusta saraiva dra etec        20        Bolívia
# 3               Rubens de faria e souza etec       140           Peru
# 4                      Machado de assis etec       144       Portugal
# ...                                      ...       ...            ...
# 13825        Vasco antonio venchiarutti etec        42       Colômbia
# 13826                   Vila formosa etec de         4         Angola
# 13827                   Vila formosa etec de        20        Bolívia
# 13828                        Zona leste etec        20        Bolívia
# 13829                        Zona leste etec        96          Japão
#
#        Número de alunos   Ano
# 0                     1  2019
# 1                     1  2019
# 2                     2  2019
# 3                     1  2019
# 4                     1  2019
# ...                 ...   ...
# 13825                 1  2022
# 13826                 1  2022
# 13827                 1  2022
# 13828                 3  2022
# 13829                 1  2022
#
# [70574 rows x 15 columns]

# %%
#Ver 5 registros aleatórios
dadosBD.sample(5)
# Out:
#       Cod Cla Clasificaçõ  Cod Dep      Dependência  Cod Dist  \
# 3354        0    Estadual       42          Leste 1       185
# 7621        2   Municipal       68      Santo andre       531
# 8894        3     Privada       60  Pindamonhangaba       436
# 8789        2   Municipal        1        Americana        19
# 1297        0    Estadual       20           Centro       515
#
#                 Distrito  Cod Mun        Município  Tipo da Escola  \
# 3354  Ermelino matarazzo      426        Sao paulo               8
# 7621         Santo andre      405      Santo andre               0
# 8894     Pindamonhangaba      327  Pindamonhangaba               0
# 8789           Americana       14        Americana               0
# 1297       Santa cecilia      426        Sao paulo               8
#
#       Código da Escola                          Nome Escola  Cod País  \
# 3354             39238  Lucio de carvalho marques professor        20
# 7621            232099              Herbert de souza creche        42
# 8894            286527                   Progressao colegio        20
# 8789            283447                Urupe casa da crianca        20
# 1297              3670     Fidelino de figueiredo professor        94
#
#      País de Origem  Número de alunos   Ano
# 3354        Bolívia                 3  2022
# 7621       Colômbia                 1  2020
# 8894        Bolívia                 2  2020
# 8789        Bolívia                 1  2021
# 1297          Iémen                 1  2021

# %% [markdown]
# #Separando as tabelas

# %%
#Tabela fato
escolaestrageiros=dadosBD[['Cod Cla','Cod Dep','Cod Dist','Cod Mun','Código da Escola','Cod País','Número de alunos','Ano']]


#Tabelas dimensôes
clasificacao=dadosBD[['Cod Cla','Clasificaçõ']]
clasificacao = clasificacao.value_counts()
dependencia=dadosBD[['Cod Dep','Dependência']]
dependencia = dependencia.value_counts()
distrito=dadosBD[['Cod Dist','Distrito']]
distrito = distrito.value_counts()
municipio=dadosBD[['Cod Mun','Município']]
municipio = municipio.value_counts()
escola=dadosBD[['Código da Escola','Nome Escola','Tipo da Escola']]
escola = escola.value_counts()
pais=dadosBD[['Cod País','País de Origem']]
pais = pais.value_counts()

# %%
print(f"Quantidades de registros na tabela principal \n{len(escolaestrageiros)} \n")
print(f"Quantidades de registros na tabela Clasificação \n{len(clasificacao)} \n")
print(f"Quantidades de registros na tabela dependencia\n{len(dependencia)} \n")
print(f"Quantidades de registros na tabela distrito\n{len(distrito)} \n")
print(f"Quantidades de registros na tabela municipio\n{len(municipio)} \n")
print(f"Quantidades de registros na tabela escola\n{len(escola)} \n")
print(f"Quantidades de registros na tabela país\n{len(pais)} \n")
# Out:
# Quantidades de registros na tabela principal
# 70574
#
# Quantidades de registros na tabela Clasificação
# 4
#
# Quantidades de registros na tabela dependencia
# 92
#
# Quantidades de registros na tabela distrito
# 647
#
# Quantidades de registros na tabela municipio
# 482
#
# Quantidades de registros na tabela escola
# 12525
#
# Quantidades de registros na tabela pais
# 188

# %% [markdown]
# #Exportando Dados

# %%
#dadosBD.to_csv('BDEducacao.csv')
clasificacao.to_csv('clasificacao.csv')
dependencia.to_csv('dependencia.csv')
distrito.to_csv('distrito.csv')
municipio.to_csv('municipio.csv')
escola.to_csv('escola.csv')
pais.to_csv('pais.csv')
escolaestrageiros.to_csv('escolaestrageiros.csv')
